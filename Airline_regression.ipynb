# %%
##################### Python
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'AppleGothic'
import numpy as np
import os
import datetime
#import dcor
import math
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 50)
import warnings
from scipy import stats
from PIL import Image
warnings.filterwarnings('ignore')
from scipy.stats import chi2
import os
# os.chdir('/Users/sss/Desktop/Data')
os.getcwd()
from IPython.core.display import display, HTML
# display(HTML("<style>.container { width: 60% !important; }</style>"))
# plt.rcParams['font.family'] = 'AppleGothic'
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
import pickle
plt.style.use(['dark_background'])
from google.colab import drive
drive.mount('/content/drive')
# df = pd.read_csv("/content/drive/My Drive/Data/chapter28_df.csv")

plt.rcParams['font.family'] = 'DejaVu Sans'
import warnings
warnings.filterwarnings("ignore", message="findfont: Font family")



#from google.colab import files
#uploaded = files.upload()

## 파일이 업로드된 후, 이름을 사용하여 불러오기
#import pandas as pd
#df = pd.read_csv(list(uploaded.keys())[0])

# from google.colab import files
# uploaded = files.upload()

# # 파일이 업로드된 후, 이름을 사용하여 불러오기
# import pandas as pd
# df = pd.read_csv(list(uploaded.keys())[0])
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Data UPloaded

# %%
df_airlines = pd.read_csv("/content/drive/My Drive/Data/airlines.csv")
df_flights = pd.read_csv("/content/drive/My Drive/Data/flights.csv")
df_tzone_meta = pd.read_csv("/content/drive/My Drive/Data/tzone_meta.csv")
df_airports = pd.read_csv("/content/drive/My Drive/Data/airports.csv")
df_planes = pd.read_csv("/content/drive/My Drive/Data/planes.csv")
df_weather = pd.read_csv("/content/drive/My Drive/Data/weather.csv")

# %%
df_airlines
# Out:
#    carrier                      name
# 0       AA    American Airlines Inc.
# 1       AS      Alaska Airlines Inc.
# 2       B6           JetBlue Airways
# 3       DL      Delta Air Lines Inc.
# 4       EV  ExpressJet Airlines Inc.
# 5       F9    Frontier Airlines Inc.
# 6       HA    Hawaiian Airlines Inc.
# 7       NK          Spirit Air Lines
# 8       OO     SkyWest Airlines Inc.
# 9       UA     United Air Lines Inc.
# 10      VX            Virgin America
# 11      WN    Southwest Airlines Co.

# %%
df_flights
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2017     10    1      27.0            2114      193.0     317.0
# 1       2017     10    1     519.0             525       -6.0     741.0
# 2       2017     10    1     544.0             545       -1.0     815.0
# 3       2017     10    1     546.0             550       -4.0     702.0
# 4       2017     10    1     552.0             600       -8.0     846.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 182919  2017      5   11    1645.0            1629       16.0    1940.0
# 182920  2017      5   11    1648.0            1649       -1.0    1836.0
# 182921  2017      5   11    1651.0            1655       -4.0    1839.0
# 182922  2017      5   11    1651.0            1655       -4.0    1828.0
# 182923  2017      5   11    1651.0            1635       16.0    1822.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df_tzone_meta
# Out:
#    tzone           tzone_name
# 0      1     America/New_York
# 1      2      America/Chicago
# 2      3       America/Denver
# 3      4      America/Phoenix
# 4      5    America/Anchorage
# 5      6  America/Los_Angeles
# 6      7         America/Adak
# 7      8     Pacific/Honolulu
# 8      9     Australia/Sydney
# 9     10      Europe/Budapest

# %%
df_airports
# Out:
#       faa                               name        lat         lon   alt  \
# 0     0V4  Brookneal/Campbell County Airport  37.141701  -79.016403   596
# 1     19S         Sublette Municipal Airport  37.491402 -100.830002  2908
# 2     23M              Clarke County Airport  32.084900  -88.738899   320
# 3     2A5                     Causey Airport  35.911800  -79.617599   723
# 4     2H0              Shelby County Airport  39.410400  -88.845398   618
# ...   ...                                ...        ...         ...   ...
# 1328  Z84                      Clear Airport  64.301201 -149.119995   552
# 1329  ZPH      Zephyrhills Municipal Airport  28.228201  -82.155899    90
# 1330  ZSY                 Scottsdale Airport  33.622898 -111.911003  1510
# 1331  ZUN                 Black Rock Airport  35.083199 -108.792000  6454
# 1332  ZZV       Zanesville Municipal Airport  39.944401  -81.892097   900
#
#        tz  dst  tzone
# 0    -5.0    A    1.0
# 1    -5.0    A    NaN
# ...

# %%
df_planes
# Out:
#      tailnum    year                      type                   manufacturer  \
# 0     N102AA  2007.0  Fixed wing single engine             AVIAT AIRCRAFT INC
# 1     N103AA  2007.0  Fixed wing single engine             AVIAT AIRCRAFT INC
# 2     N103SY  2014.0   Fixed wing multi engine                    EMBRAER S A
# 3     N10575  2002.0   Fixed wing multi engine                        EMBRAER
# 4     N105AA  1978.0  Fixed wing single engine                         CESSNA
# ...      ...     ...                       ...                            ...
# 3516  N997AT  2002.0   Fixed wing multi engine                         BOEING
# 3517  N997DL  1992.0   Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3518  N998AT  2002.0   Fixed wing multi engine                         BOEING
# 3519  N998DL  1992.0   Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3520  N999DN  1992.0   Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
# ...

# %%
df_weather
# Out:
#       origin    year  month  day  hour  temp  dewp  humid  wind_dir  \
# 0        EWR  2017.0    1.0    1     0   NaN   NaN    NaN     200.0
# 1        EWR  2017.0    1.0    1     1   NaN   NaN    NaN     220.0
# 2        EWR  2017.0    1.0    1     2   NaN   NaN    NaN     190.0
# 3        EWR  2017.0    1.0    1     3   NaN   NaN    NaN     190.0
# 4        EWR  2017.0    1.0    1     4   NaN   NaN    NaN     220.0
# ...      ...     ...    ...  ...   ...   ...   ...    ...       ...
# 26196    LGA  2017.0   12.0   30    19   NaN   NaN    NaN     210.0
# 26197    LGA  2017.0   12.0   30    20   NaN   NaN    NaN     200.0
# 26198    LGA  2017.0   12.0   30    21   NaN   NaN    NaN     280.0
# 26199    LGA  2017.0   12.0   30    22   NaN   NaN    NaN     260.0
# 26200    LGA  2017.0   12.0   30    23   NaN   NaN    NaN     250.0
#
#        wind_speed  wind_gust  precip  pressure  visib            time_hour
# 0        17.26170  19.864419     NaN       NaN   10.0  2017-01-01 08:00:00
# ...

# %%
df_weather
# Out:
#       origin    year  month  day  hour  temp  dewp  humid  wind_dir  \
# 0        EWR  2017.0    1.0    1     0   NaN   NaN    NaN     200.0
# 1        EWR  2017.0    1.0    1     1   NaN   NaN    NaN     220.0
# 2        EWR  2017.0    1.0    1     2   NaN   NaN    NaN     190.0
# 3        EWR  2017.0    1.0    1     3   NaN   NaN    NaN     190.0
# 4        EWR  2017.0    1.0    1     4   NaN   NaN    NaN     220.0
# ...      ...     ...    ...  ...   ...   ...   ...    ...       ...
# 26196    LGA  2017.0   12.0   30    19   NaN   NaN    NaN     210.0
# 26197    LGA  2017.0   12.0   30    20   NaN   NaN    NaN     200.0
# 26198    LGA  2017.0   12.0   30    21   NaN   NaN    NaN     280.0
# 26199    LGA  2017.0   12.0   30    22   NaN   NaN    NaN     260.0
# 26200    LGA  2017.0   12.0   30    23   NaN   NaN    NaN     250.0
#
#        wind_speed  wind_gust  precip  pressure  visib            time_hour
# 0        17.26170  19.864419     NaN       NaN   10.0  2017-01-01 08:00:00
# ...

# %%
df_flights.shape
# Out:
# (182924, 19)

# %%
df_flights.isnull().sum()
# Out:
# year                 0
# month                0
# day                  0
# dep_time          4283
# sched_dep_time       0
# dep_delay         4284
# arr_time          4408
# sched_arr_time       0
# arr_delay         4811
# carrier              0
# flight               0
# tailnum            488
# origin               0
# dest                 0
# air_time          4811
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
# df_flights = df_flights.dropna()

# %%
df_flights.isnull().sum()
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         0
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          0
# distance          0
# hour              0
# minute            0
# time_hour         0
# dtype: int64

# %%
df_flights
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2017     10    1      27.0            2114      193.0     317.0
# 1       2017     10    1     519.0             525       -6.0     741.0
# 2       2017     10    1     544.0             545       -1.0     815.0
# 3       2017     10    1     546.0             550       -4.0     702.0
# 4       2017     10    1     552.0             600       -8.0     846.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 182919  2017      5   11    1645.0            1629       16.0    1940.0
# 182920  2017      5   11    1648.0            1649       -1.0    1836.0
# 182921  2017      5   11    1651.0            1655       -4.0    1839.0
# 182922  2017      5   11    1651.0            1655       -4.0    1828.0
# 182923  2017      5   11    1651.0            1635       16.0    1822.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df_airports['faa'].value_counts()
# Out:
# faa
# 0V4    1
# NUI    1
# NTD    1
# NSE    1
# NRB    1
#       ..
# FTK    1
# FTG    1
# FST    1
# FSM    1
# ZZV    1
# Name: count, Length: 1333, dtype: int64

# %%
df_flights['dest'].value_counts()
# Out:
# dest
# LAX    10781
# ATL     9891
# MCO     9868
# FLL     9672
# BOS     9575
#        ...
# BZN       37
# ACK       30
# HDN       24
# MVY       16
# ALB       14
# Name: count, Length: 105, dtype: int64

# %%
np.intersect1d(df_flights.dest.unique(), df_airports.faa.unique())
# Out:
# array(['ABQ', 'ACK', 'ALB', 'ATL', 'AUS', 'AVL', 'AVP', 'BDL', 'BGR',
#        'BHM', 'BNA', 'BOS', 'BTV', 'BUF', 'BUR', 'BWI', 'BZN', 'CAE',
#        'CAK', 'CHA', 'CHO', 'CHS', 'CLE', 'CLT', 'CMH', 'CVG', 'DAB',
#        'DAL', 'DAY', 'DCA', 'DEN', 'DFW', 'DSM', 'DTW', 'EGE', 'FLL',
#        'FNT', 'FWA', 'GRR', 'GSO', 'GSP', 'HDN', 'HNL', 'HOU', 'IAD',
#        'IAH', 'IND', 'JAC', 'JAX', 'LAS', 'LAX', 'LEX', 'LGB', 'MCI',
#        'MCO', 'MDW', 'MEM', 'MHT', 'MIA', 'MKE', 'MSN', 'MSP', 'MSY',
#        'MTJ', 'MVY', 'MYR', 'OAK', 'OMA', 'ORD', 'ORF', 'PBI', 'PDX',
#        'PHL', 'PHX', 'PIT', 'PSP', 'PVD', 'PWM', 'RDU', 'RIC', 'RNO',
#        'ROC', 'RSW', 'SAN', 'SAT', 'SAV', 'SBN', 'SDF', 'SEA', 'SFO',
#        'SJC', 'SLC', 'SMF', 'SNA', 'SRQ', 'STL', 'SYR', 'TPA', 'TUS',
#        'TYS', 'XNA'], dtype=object)

# %%
df_planes.shape
# Out:
# (3521, 9)

# %%
df_planes.isnull().sum()
# Out:
# tailnum           0
# year            102
# type              0
# manufacturer      0
# model             0
# engines           0
# seats            10
# engine            0
# dtype: int64

# %%
# df_planes.drop('speed', axis=1, inplace=True)

# %%
df_weather.shape
# Out:
# (26201, 15)

# %%
# df_weather.drop(['temp', 'dewp', 'humid', 'precip', 'pressure'], axis=1, inplace=True)

# %% [markdown]
# <!--  -->

# %%
df_weather.isnull().sum()
# Out:
# origin           0
# year             0
# month            0
# day              0
# hour             0
# wind_dir      2661
# wind_speed    2647
# wind_gust     2647
# visib           11
# time_hour        0
# dtype: int64

# %%
df_weather.head(5)
# Out:
#   origin    year  month  day  hour  wind_dir  wind_speed  wind_gust  visib  \
# 0    EWR  2017.0    1.0    1     0     200.0    17.26170  19.864419   10.0
# 1    EWR  2017.0    1.0    1     1     220.0    16.11092  18.540125   10.0
# 2    EWR  2017.0    1.0    1     2     190.0    11.50780  13.242946   10.0
# 3    EWR  2017.0    1.0    1     3     190.0     8.05546   9.270062   10.0
# 4    EWR  2017.0    1.0    1     4     220.0     9.20624  10.594357   10.0
#
#              time_hour
# 0  2017-01-01 08:00:00
# 1  2017-01-01 09:00:00
# 2  2017-01-01 10:00:00
# 3  2017-01-01 11:00:00
# 4  2017-01-01 12:00:00

# %%
df_weather.sort_values(['origin', 'time_hour']).groupby('origin').apply(lambda x: x.fillna(method='ffill'))
# Out:
#              origin    year  month  day  hour  wind_dir  wind_speed  \
# origin
# EWR    0        EWR  2017.0    1.0    1     0     200.0    17.26170
#        1        EWR  2017.0    1.0    1     1     220.0    16.11092
#        2        EWR  2017.0    1.0    1     2     190.0    11.50780
#        3        EWR  2017.0    1.0    1     3     190.0     8.05546
#        4        EWR  2017.0    1.0    1     4     220.0     9.20624
# ...             ...     ...    ...  ...   ...       ...         ...
# LGA    26196    LGA  2017.0   12.0   30    19     210.0     9.20624
#        26197    LGA  2017.0   12.0   30    20     200.0    10.35702
#        26198    LGA  2017.0   12.0   30    21     280.0     8.05546
#        26199    LGA  2017.0   12.0   30    22     260.0    10.35702
#        26200    LGA  2017.0   12.0   30    23     250.0    11.50780
#
#               wind_gust  visib            time_hour
# origin
# EWR    0      19.864419   10.0  2017-01-01 08:00:00
# ...

# %%
df_weather = df_weather.sort_values(["origin", "time_hour"]).groupby("origin").apply(lambda x: x.fillna(method="ffill").fillna(method="bfill"))

# %%
# df_weather.reset_index(drop=True, inplace=True)

# %%
df_weather
# Out:
#       origin    year  month  day  hour  wind_dir  wind_speed  wind_gust  \
# 0        EWR  2017.0    1.0    1     0     200.0    17.26170  19.864419
# 1        EWR  2017.0    1.0    1     1     220.0    16.11092  18.540125
# 2        EWR  2017.0    1.0    1     2     190.0    11.50780  13.242946
# 3        EWR  2017.0    1.0    1     3     190.0     8.05546   9.270062
# 4        EWR  2017.0    1.0    1     4     220.0     9.20624  10.594357
# ...      ...     ...    ...  ...   ...       ...         ...        ...
# 26196    LGA  2017.0   12.0   30    19     210.0     9.20624  10.594357
# 26197    LGA  2017.0   12.0   30    20     200.0    10.35702  11.918651
# 26198    LGA  2017.0   12.0   30    21     280.0     8.05546   9.270062
# 26199    LGA  2017.0   12.0   30    22     260.0    10.35702  11.918651
# 26200    LGA  2017.0   12.0   30    23     250.0    11.50780  13.242946
#
#        visib            time_hour
# 0       10.0  2017-01-01 08:00:00
# ...

# %%
df_flight_and_airport = pd.merge(df_flights, df_airports, how='left', left_on='dest', right_on='faa')
df_flight_and_airport
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0       2017     10    1      27.0            2114      193.0     317.0
# 1       2017     10    1     519.0             525       -6.0     741.0
# 2       2017     10    1     544.0             545       -1.0     815.0
# 3       2017     10    1     546.0             550       -4.0     702.0
# 4       2017     10    1     552.0             600       -8.0     846.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 178108  2017      5   11    1645.0            1629       16.0    1940.0
# 178109  2017      5   11    1648.0            1649       -1.0    1836.0
# 178110  2017      5   11    1651.0            1655       -4.0    1839.0
# 178111  2017      5   11    1651.0            1655       -4.0    1828.0
# 178112  2017      5   11    1651.0            1635       16.0    1822.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# ...

# %%
df_planes
# Out:
#      tailnum    year                      type                   manufacturer  \
# 0     N102AA  2007.0  Fixed wing single engine             AVIAT AIRCRAFT INC
# 1     N103AA  2007.0  Fixed wing single engine             AVIAT AIRCRAFT INC
# 2     N103SY  2014.0   Fixed wing multi engine                    EMBRAER S A
# 3     N10575  2002.0   Fixed wing multi engine                        EMBRAER
# 4     N105AA  1978.0  Fixed wing single engine                         CESSNA
# ...      ...     ...                       ...                            ...
# 3516  N997AT  2002.0   Fixed wing multi engine                         BOEING
# 3517  N997DL  1992.0   Fixed wing multi engine  MCDONNELL DOUGLAS AIRCRAFT CO
# 3518  N998AT  2002.0   Fixed wing multi engine                         BOEING
# 3519  N998DL  1992.0   Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
# 3520  N999DN  1992.0   Fixed wing multi engine  MCDONNELL DOUGLAS CORPORATION
#
# ...
